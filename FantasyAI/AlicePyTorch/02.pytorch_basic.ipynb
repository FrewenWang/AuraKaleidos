# %%
import torch
# 创建一个空值矩阵
x = torch.empty(5, 3)
x
# Out:
# 运行具有“base (Python 3.13.12)”的单元格需要ipykernel包。
#
# 使用所需的包 <a href='command:jupyter.createPythonEnvAndSelectController'>创建 Python 环境</a>。
#
# 或使用命令“conda install -n base ipykernel --update-deps --force-reinstall”安装“ipykernel”

# %%
# 创建一个
x = torch.rand(5,3)
x

# %%
 # 创建一个
x = torch.zeros(5,3)
x

# %%
 # 创建一个tensor. tensor才是torch中使用的格式
x = torch.tensor([5,3])
x

# %%
# 创建一个
x = x.new_ones(5,3,dtype=torch.double)

x = torch.randn_like(x,dtype=torch.double)

x

x.size()

# %%
# torch可以和numpy的进行协同操作
a = torch.ones(5)
b = a.numpy()
b

# %%
# torch的基本计算方法
y = torch.rand(5,3)

x+y

# %%
torch.add(x,y)

# %%
### view操作可以改变矩阵维度

# %%
x = torch.randn(4, 4)
y = x.view(16)
z = x.view(-1, 8) 
print(x.size(), y.size(), z.size())

# %%
### 与Numpy的协同操作

# %%
a = torch.ones(5)
b = a.numpy()
b

# %%
import numpy as np
a = np.ones(5)
b = torch.from_numpy(a)
b
