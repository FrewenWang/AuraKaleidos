# %%
import tensorflow as tf

# 调用Tensorflow的常量
hello = tf.constant('hello tensorflow2.0!')

# 在tensorflow1.0中恶心的session.run.在tf2.0中终于不用使用了。
# sess = tf.Session()
# print(sess.run(hello))
# 我们直接打印hello 他其实是一个Tensor张量
print(hello)
print(tf.__version__)  # 打印TensorFlow版本号
print(tf.__file__)  # 打印TensorFlow安装路径



# ds_tensors = tf.data.Dataset.from_tensor_slices([6,5,4,3,2,1])

# import tempfile

# # 
# _filename = tempfile.mkstemp()

# print(filename)

# # 循环打开文件
# with open(filename,'w') as f:
#     f.write("""
#     Line1
#     Line2
#     Lin23
#     """)

# ds_file = tf.data.TextLineDataset(filename)
# Out:
# tf.Tensor(b'hello tensorflow2.0!', shape=(), dtype=string)
# 2.16.1
# /home/baiduiov/tools/miniconda3/lib/python3.9/site-packages/tensorflow/__init__.py
